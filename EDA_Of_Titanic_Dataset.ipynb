# %% [markdown]
# # Exploratory Data Analysis Of Titanic Ship Traviling Passenger Dataset  S  / NS:-
# <img src = "http://mybestguide.org/wp-content/uploads/2020/07/data_analytics_banner.png" >

# %%
#Import Required Library For Titanic Dataset

import numpy as np
import pandas as pd
import scipy as sp
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Un-Clean Data   :- dataset = pd.read_csv('train.csv')
#
# ### Clean Data :- dataset = pd.read_csv('titanic_dataset_2.csv')
#
# ### Hear I am using Unclean Data To Show You For Better Understanding

# %%
# Import Titanic Dataset 

uc_dataset = pd.read_csv('train.csv')

# %%
#Visualize Head Of Imported Dataset

uc_dataset.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#Visualize Tail Of Imported Dataset

uc_dataset.tail(5)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
#Cheack Dataset Clean Or Not (Note :- If Not Then Clean It)

uc_dataset.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
#Cheack Dataset Clean Or Not In Sum Formate (Note :- If Not Then Clean It)

uc_dataset.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
#Check Discription Of Dataset

uc_dataset.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
#Evaluate Column Value For Better Understanding

uc_dataset.nunique()
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             88
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Cabin          147
# Embarked         3
# dtype: int64

# %%
# Check The Image of Cleaning Data

sns.heatmap(uc_dataset.isnull(), yticklabels = False , cbar = False)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Hear I Am Taking Clean Data

# %%
# Import Titanic Dataset 

c_dataset = pd.read_csv('titanic_dataset_2.csv')

# %%
#Visualize Head Of Imported Dataset

c_dataset.head(5)
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked  PassengerId
# 0         0       3    1  22.0      1      0   7.2500       0.0            1
# 1         1       1    0  38.0      1      0  71.2833       1.0            2
# 2         1       3    0  26.0      0      0   7.9250       0.0            3
# 3         1       1    0  35.0      1      0  53.1000       0.0            4
# 4         0       3    1  35.0      0      0   8.0500       0.0            5

# %%
#Cheack Dataset Clean Or Not (Note :- If Not Then Clean It)

c_dataset.isnull()
# Out:
#      Survived  Pclass    Sex    Age  SibSp  Parch   Fare  Embarked  \
# 0       False   False  False  False  False  False  False     False
# 1       False   False  False  False  False  False  False     False
# 2       False   False  False  False  False  False  False     False
# 3       False   False  False  False  False  False  False     False
# 4       False   False  False  False  False  False  False     False
# ..        ...     ...    ...    ...    ...    ...    ...       ...
# 886     False   False  False  False  False  False  False     False
# 887     False   False  False  False  False  False  False     False
# 888     False   False  False  False  False  False  False     False
# 889     False   False  False  False  False  False  False     False
# 890     False   False  False  False  False  False  False     False
#
#      PassengerId
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
# ..           ...
# 886        False
# ...

# %%
#Cheack Dataset Clean Or Not In Sum Formate (Note :- If Not Then Clean It)

c_dataset.isnull().sum()
# Out:
# Survived       0
# Pclass         0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Fare           0
# Embarked       0
# PassengerId    0
# dtype: int64

# %%
#Check Discription Of Dataset

c_dataset.describe()
# Out:
#          Survived      Pclass         Sex         Age       SibSp       Parch  \
# count  891.000000  891.000000  891.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642    0.647587   29.699118    0.523008    0.381594
# std      0.486592    0.836071    0.477990   13.002015    1.102743    0.806057
# min      0.000000    1.000000    0.000000    0.420000    0.000000    0.000000
# 25%      0.000000    2.000000    0.000000   22.000000    0.000000    0.000000
# 50%      0.000000    3.000000    1.000000   29.699118    0.000000    0.000000
# 75%      1.000000    3.000000    1.000000   35.000000    1.000000    0.000000
# max      1.000000    3.000000    1.000000   80.000000    8.000000    6.000000
#
#              Fare    Embarked  PassengerId
# count  891.000000  891.000000   891.000000
# mean    32.204208    0.102362   446.000000
# std     49.693429    0.514601   257.353842
# min      0.000000   -1.000000     1.000000
# 25%      7.910400    0.000000   223.500000
# ...

# %%
# Columns Visulzation In Dataset

uc_dataset.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
# Check The Image of Cleaning Data

sns.heatmap(c_dataset.isnull(), yticklabels = False , cbar = False)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Data Visualization In Graph Formate

# %%
uc_dataset.plot()
# Out:
# <AxesSubplot:>

# %%
# Histogram's Graph Representation Of 


plt.title("Graph Representation's B/N " , fontsize = 20)
uc_dataset["Age"].plot.hist()
uc_dataset["Fare"].plot.hist()
uc_dataset["Pclass"].plot.hist()
uc_dataset["Survived"].plot.hist()
# Out:
# <AxesSubplot:title={'center':"Graph Representation's B/N "}, ylabel='Frequency'>

# %%
# Heatmap Of Dataset

import numpy as np; np.random.seed(0)
import seaborn as sns; sns.set_theme()
uniform_data = np.random.rand(10, 20)
ax = sns.heatmap(uniform_data , center=0 )

# %%
ax = sns.heatmap(c_dataset, cmap="YlGnBu")

# %%
# Compute the correlation matrix
corr = dataset.corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <AxesSubplot:>

# %%
# Load the brain networks dataset, select subset, and collapse the multi-index
df = sns.load_dataset("brain_networks", header=[0, 1, 2], index_col=0)

# Compute a correlation matrix and convert to long-form
corr_mat = dataset.corr().stack().reset_index(name="correlation")

# Draw each cell as a scatter point with varying size and color
g = sns.relplot(
    data=corr_mat,
    x="level_0", y="level_1", hue="correlation", size="correlation",
    palette="vlag", hue_norm=(-1, 1), edgecolor=".7",
    height=10, sizes=(50, 250), size_norm=(-.2, .8),
)

# Tweak the figure to finalize
g.set(xlabel="", ylabel="", aspect="equal")
g.despine(left=True, bottom=True)
g.ax.margins(.02)
for label in g.ax.get_xticklabels():
    label.set_rotation(90)
for artist in g.legend.legendHandles:
    artist.set_edgecolor(".7")
